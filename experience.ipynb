# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_job_categories.csv")
df
# Out:
#                                                  Title  \
# 0    ['Manager - Penetration Testing - Cyber Securi...
# 1                               ['Penetration Tester']
# 2                   ['Penetration Testing Specialist']
# 3    ['Application Security Engineer/ Penetration t...
# 4                               ['Penetration Tester']
# ..                                                 ...
# 493                      ['Junior Penetration Tester']
# 494                             ['Penetration Tester']
# 495                         ['Sr. Penetration Tester']
# 496                             ['Penetration Tester']
# 497                 ['Penetration Tester (Full Time)']
#
#                                            Description Company  \
# 0    ["  Manager - Penetration Testing - Cyber Secu...    [[]]
# 1    ['  Penetration Tester - Sydney Central Busine...    [[]]
# 2    ["  Penetration Testing Specialist - South Aus...    [[]]
# 3    ["  Application Security Engineer/ Penetration...    [[]]
# 4    ["  Penetration Tester - Brisbane QLD - Indeed...    [[]]
# ..                                                 ...     ...
# 493  ["  Junior Penetration Tester - Charleston, SC...    [[]]
# 494  ["  Penetration Tester - Lafayette, CO 80026 -...    [[]]
# 495  ["  Sr. Penetration Tester - Beaverton, OR 970...    [[]]
# 496  ["  Penetration Tester - Arlington, VA 22209 -...    [[]]
# 497  ["  Penetration Tester (Full Time) - North Car...    [[]]
#
#             worktype  ID Date Location Link Title-Category
# 0               [[]] NaN  NaN      NaN  NaN     technology
# 1               [[]] NaN  NaN      NaN  NaN      pentester
# 2    [['Full-time']] NaN  NaN      NaN  NaN     specialist
# 3               [[]] NaN  NaN      NaN  NaN       engineer
# 4    [['Full-time']] NaN  NaN      NaN  NaN      pentester
# ..               ...  ..  ...      ...  ...            ...
# 493             [[]] NaN  NaN      NaN  NaN         junior
# 494             [[]] NaN  NaN      NaN  NaN      pentester
# 495  [['Full-time']] NaN  NaN      NaN  NaN         senior
# 496  [['Full-time']] NaN  NaN      NaN  NaN      pentester
# 497  [['Full-time']] NaN  NaN      NaN  NaN      pentester
#
# [498 rows x 9 columns]

# %%
expected_experience = ['1 year', '2 years', '3 years', '4 years', '5 years', '2+ years', '3+ years', '4+ years', '5+ years', '7+ years',
                  '8+ years', '2-5 years', '3-5 years', '5-8 years']

# %%
title_categories_list = ['pentester', 'specialist', 'engineer', 'lead', 'consultant', 'junior', 'security', 'web', 'senior', 'analyst', 'manager', 'red', 'vulnerability', 'technology', 'clearance', 'remote', 'team', 'secret', 'network']

# %%
data = {'Expected_Experience': expected_experience}
new_df = pd.DataFrame(data=data)
new_df 

for category in title_categories_list: 
    temp_df = df.loc[df["Title-Category"] == category]
    temp_df
    expected_experience_dict = {x.lower():0 for x in expected_experience}
    for index, row in temp_df.iterrows():
        job_description = row["Description"]
        for key, value in expected_experience_dict.items():
            if key in job_description.lower():
                expected_experience_dict[key] += 1
    count_column=[value for key,value in expected_experience_dict.items()]
    new_df[category] = count_column

new_df
# Out:
#    Expected_Experience  pentester  specialist  engineer  lead  consultant  \
# 0               1 year         17           0         1     0           2
# 1              2 years         26           0         2     0           3
# 2              3 years         33           0         2     2           1
# 3              4 years          9           0         0     0           0
# 4              5 years         31           0         3     3           4
# 5             2+ years          5           0         1     0           0
# 6             3+ years         10           0         1     1           0
# 7             4+ years          5           0         0     2           0
# 8             5+ years         22           1         1     3           0
# 9             7+ years         13           0         0     0           0
# 10            8+ years          2           0         0     1           0
# 11           2-5 years          8           0         1     0           0
# 12           3-5 years          5           0         0     0           0
# 13           5-8 years          0           0         0     0           0
#
#     junior  security  web  senior  analyst  manager  red  vulnerability  \
# 0        0         2    0       0        0        0    1              0
# 1        1         0    2       2        1        0    1              0
# 2        0         4    1       2        0        0    0              0
# 3        1         3    0       0        0        0    2              0
# 4        1         3    1       7        1        0    4              2
# 5        0         1    0       2        2        0    0              0
# 6        0         2    1       2        0        0    2              3
# 7        0         1    0       0        0        0    1              0
# 8        0         0    0      11        1        2    3              3
# 9        0         0    0       2        0        0    0              0
# 10       0         0    1       0        0        0    1              0
# 11       0         0    0       0        0        0    0              0
# 12       0         0    0       0        0        0    0              0
# 13       0         0    0       0        0        0    0              0
#
#     technology  clearance  remote  team  secret  network
# 0            0          0       0     0      18        0
# 1            0          1       0     0       0        0
# 2            0          0       0     0       1        2
# 3            0          0       0     0       0        0
# 4            0          0       1     0       0        3
# 5            0          0       2     0       1        0
# 6            0          0       0     0       1        1
# 7            3          0       0     0       0        0
# 8            0          0       1     0       2        0
# 9            0          0       0     0       0        0
# 10           0          0       0     0       0        1
# 11           0          0       0     0       0        0
# 12           0          0       1     0       0        0
# 13           0          0       0     0       0        0

# %%
# drop rows with zeros only
new_df = new_df.set_index('Expected_Experience')
new_df = new_df.loc[~new_df.apply(lambda row: (row==0).all(), axis=1)]
new_df
# Out:
#                      pentester  specialist  engineer  lead  consultant  \
# Expected_Experience
# 1 year                      17           0         1     0           2
# 2 years                     26           0         2     0           3
# 3 years                     33           0         2     2           1
# 4 years                      9           0         0     0           0
# 5 years                     31           0         3     3           4
# 2+ years                     5           0         1     0           0
# 3+ years                    10           0         1     1           0
# 4+ years                     5           0         0     2           0
# 5+ years                    22           1         1     3           0
# 7+ years                    13           0         0     0           0
# 8+ years                     2           0         0     1           0
# 2-5 years                    8           0         1     0           0
# 3-5 years                    5           0         0     0           0
#
#                      junior  security  web  senior  analyst  manager  red  \
# Expected_Experience
# 1 year                    0         2    0       0        0        0    1
# 2 years                   1         0    2       2        1        0    1
# 3 years                   0         4    1       2        0        0    0
# 4 years                   1         3    0       0        0        0    2
# 5 years                   1         3    1       7        1        0    4
# 2+ years                  0         1    0       2        2        0    0
# 3+ years                  0         2    1       2        0        0    2
# 4+ years                  0         1    0       0        0        0    1
# 5+ years                  0         0    0      11        1        2    3
# 7+ years                  0         0    0       2        0        0    0
# 8+ years                  0         0    1       0        0        0    1
# 2-5 years                 0         0    0       0        0        0    0
# 3-5 years                 0         0    0       0        0        0    0
#
#                      vulnerability  technology  clearance  remote  team  \
# Expected_Experience
# 1 year                           0           0          0       0     0
# 2 years                          0           0          1       0     0
# 3 years                          0           0          0       0     0
# 4 years                          0           0          0       0     0
# 5 years                          2           0          0       1     0
# 2+ years                         0           0          0       2     0
# 3+ years                         3           0          0       0     0
# 4+ years                         0           3          0       0     0
# 5+ years                         3           0          0       1     0
# 7+ years                         0           0          0       0     0
# 8+ years                         0           0          0       0     0
# 2-5 years                        0           0          0       0     0
# 3-5 years                        0           0          0       1     0
#
#                      secret  network
# Expected_Experience
# 1 year                   18        0
# 2 years                   0        0
# 3 years                   1        2
# 4 years                   0        0
# 5 years                   0        3
# 2+ years                  1        0
# 3+ years                  1        1
# 4+ years                  0        0
# 5+ years                  2        0
# 7+ years                  0        0
# 8+ years                  0        1
# 2-5 years                 0        0
# 3-5 years                 0        0

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(style="white")
import itertools
# Out:
# /Users/pragyakaushik/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fig, axes = plt.subplots(19, 1, sharex=True, figsize=(10,18))
fig.suptitle('Expected Experience VS Job Categories')

# set palette 
palette = itertools.cycle(sns.color_palette())

idx = 0
for item in title_categories_list[::-1]:
    c = next(palette)
    sns.barplot(ax=axes[idx], x=new_df.index, y=new_df[item], color=c)
    axes[idx].set_title(item, fontsize=15, loc='left',pad=-14)
    axes[idx].set(xlabel=None, ylabel='frequency') 
    if idx == 18:
        axes[idx].set_xticklabels(
            axes[idx].get_xticklabels(), 
            rotation=45, 
            horizontalalignment='right',
            fontweight='light',
            fontsize=14
        )
    idx+=1
