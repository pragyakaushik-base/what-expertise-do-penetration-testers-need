# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset_job_categories.csv")
df
# Out:
#                                                  Title  \
# 0    ['Manager - Penetration Testing - Cyber Securi...
# 1                               ['Penetration Tester']
# 2                   ['Penetration Testing Specialist']
# 3    ['Application Security Engineer/ Penetration t...
# 4                               ['Penetration Tester']
# ..                                                 ...
# 493                      ['Junior Penetration Tester']
# 494                             ['Penetration Tester']
# 495                         ['Sr. Penetration Tester']
# 496                             ['Penetration Tester']
# 497                 ['Penetration Tester (Full Time)']
#
#                                            Description Company  \
# 0    ["  Manager - Penetration Testing - Cyber Secu...    [[]]
# 1    ['  Penetration Tester - Sydney Central Busine...    [[]]
# 2    ["  Penetration Testing Specialist - South Aus...    [[]]
# 3    ["  Application Security Engineer/ Penetration...    [[]]
# 4    ["  Penetration Tester - Brisbane QLD - Indeed...    [[]]
# ..                                                 ...     ...
# 493  ["  Junior Penetration Tester - Charleston, SC...    [[]]
# 494  ["  Penetration Tester - Lafayette, CO 80026 -...    [[]]
# 495  ["  Sr. Penetration Tester - Beaverton, OR 970...    [[]]
# 496  ["  Penetration Tester - Arlington, VA 22209 -...    [[]]
# 497  ["  Penetration Tester (Full Time) - North Car...    [[]]
#
#             worktype  ID Date Location Link Title-Category
# 0               [[]] NaN  NaN      NaN  NaN     technology
# 1               [[]] NaN  NaN      NaN  NaN      pentester
# 2    [['Full-time']] NaN  NaN      NaN  NaN     specialist
# 3               [[]] NaN  NaN      NaN  NaN       engineer
# 4    [['Full-time']] NaN  NaN      NaN  NaN      pentester
# ..               ...  ..  ...      ...  ...            ...
# 493             [[]] NaN  NaN      NaN  NaN         junior
# 494             [[]] NaN  NaN      NaN  NaN      pentester
# 495  [['Full-time']] NaN  NaN      NaN  NaN         senior
# 496  [['Full-time']] NaN  NaN      NaN  NaN      pentester
# 497  [['Full-time']] NaN  NaN      NaN  NaN      pentester
#
# [498 rows x 9 columns]

# %%
languages = ['Java', 'Python', 'HTML', 'CSS', 'JavaScript', 'XML', 'jQuery', 'C#', 'JSON', 'Scala', 'ASP', '.NET', 'Objective C', 'Go', 'Rust', 'PHP', 'Ruby', 'Perl']

# %%
title_categories_list = ['pentester', 'specialist', 'engineer', 'lead', 'consultant', 'junior', 'security', 'web', 'senior', 'analyst', 'manager', 'red', 'vulnerability', 'technology', 'clearance', 'remote', 'team', 'secret', 'network']

# %%
data = {'Languages': languages}
new_df = pd.DataFrame(data=data)
new_df 

for category in title_categories_list: 
    temp_df = df.loc[df["Title-Category"] == category]
    languages_dict = {skill.lower():0 for skill in languages}
    for index, row in temp_df.iterrows():
        job_description = row["Description"]
        for key, value in languages_dict.items():
            if key in job_description.lower():
                languages_dict[key] += 1
#     print(languages_dict)
    count_column=[value for key,value in languages_dict.items()]
    new_df[category] = count_column

new_df
# Out:
#       Languages  pentester  specialist  engineer  lead  consultant  junior  \
# 0          Java         60           1         3     2           8       2
# 1        Python         77           1         8     3           8       4
# 2          HTML          3           0         0     0           0       1
# 3           CSS          7           0         2     0           1       0
# 4    JavaScript         30           0         2     2           2       0
# 5           XML          2           0         0     0           0       0
# 6        jQuery          0           0         0     0           0       0
# 7            C#         20           0         0     1           1       0
# 8          JSON          2           0         0     0           0       0
# 9         Scala         15           1         5     0           0       1
# 10          ASP        114           3        10     3           9       4
# 11         .NET         20           0         1     1           3       0
# 12  Objective C          4           0         0     0           0       0
# 13           Go        192          10        20     9          13       7
# 14         Rust         40           4         3     3           1       2
# 15          PHP         30           0         2     1           2       0
# 16         Ruby         45           1         3     1           3       3
# 17         Perl         38           1         4     2           1       2
#
#     security  web  senior  analyst  manager  red  vulnerability  technology  \
# 0          6    4       6        2        0    3              1           1
# 1          6    5      12        2        1    7              4           1
# 2          0    0       0        0        0    1              0           0
# 3          0    0       0        0        1    1              0           0
# 4          2    3       5        0        0    1              0           0
# 5          0    1       1        0        0    1              0           0
# 6          0    0       0        0        0    0              0           0
# 7          1    3       5        2        0    2              0           1
# 8          0    1       4        0        0    0              0           0
# 9          0    0       8        0        2    0              0           1
# 10        15    5      25        2        3   10              8           1
# 11         1    2       2        2        1    3              0           1
# 12         0    0       0        0        0    0              0           0
# 13        18    9      35        7        5   11              7           4
# 14         1    0       9        1        0    0              2           3
# 15         5    1       4        2        0    0              0           1
# 16         5    1       8        2        0    3              0           1
# 17         1    1       6        0        0    2              1           0
#
#     clearance  remote  team  secret  network
# 0           0       3     0      32        1
# 1           0       4     0      32        2
# 2           0       0     0       0        0
# 3           0       0     0       0        0
# 4           0       2     0       0        0
# 5           0       0     0       0        0
# 6           0       0     0       0        0
# 7           0       1     0      32        1
# 8           0       0     0       0        0
# 9           0       0     0       0        1
# 10          1       9     0      32        2
# 11          0       0     0      32        0
# 12          0       0     0       0        0
# 13          1       9     1      34        3
# 14          0       4     2      32        2
# 15          0       1     0       0        0
# 16          0       1     0       0        1
# 17          0       0     0      32        1

# %%
# drop rows with zeros only
new_df = new_df.set_index('Languages')
new_df = new_df.loc[~new_df.apply(lambda row: (row==0).all(), axis=1)]
new_df
# Out:
#              pentester  specialist  engineer  lead  consultant  junior  \
# Languages
# Java                60           1         3     2           8       2
# Python              77           1         8     3           8       4
# HTML                 3           0         0     0           0       1
# CSS                  7           0         2     0           1       0
# JavaScript          30           0         2     2           2       0
# XML                  2           0         0     0           0       0
# C#                  20           0         0     1           1       0
# JSON                 2           0         0     0           0       0
# Scala               15           1         5     0           0       1
# ASP                114           3        10     3           9       4
# .NET                20           0         1     1           3       0
# Objective C          4           0         0     0           0       0
# Go                 192          10        20     9          13       7
# Rust                40           4         3     3           1       2
# PHP                 30           0         2     1           2       0
# Ruby                45           1         3     1           3       3
# Perl                38           1         4     2           1       2
#
#              security  web  senior  analyst  manager  red  vulnerability  \
# Languages
# Java                6    4       6        2        0    3              1
# Python              6    5      12        2        1    7              4
# HTML                0    0       0        0        0    1              0
# CSS                 0    0       0        0        1    1              0
# JavaScript          2    3       5        0        0    1              0
# XML                 0    1       1        0        0    1              0
# C#                  1    3       5        2        0    2              0
# JSON                0    1       4        0        0    0              0
# Scala               0    0       8        0        2    0              0
# ASP                15    5      25        2        3   10              8
# .NET                1    2       2        2        1    3              0
# Objective C         0    0       0        0        0    0              0
# Go                 18    9      35        7        5   11              7
# Rust                1    0       9        1        0    0              2
# PHP                 5    1       4        2        0    0              0
# Ruby                5    1       8        2        0    3              0
# Perl                1    1       6        0        0    2              1
#
#              technology  clearance  remote  team  secret  network
# Languages
# Java                  1          0       3     0      32        1
# Python                1          0       4     0      32        2
# HTML                  0          0       0     0       0        0
# CSS                   0          0       0     0       0        0
# JavaScript            0          0       2     0       0        0
# XML                   0          0       0     0       0        0
# C#                    1          0       1     0      32        1
# JSON                  0          0       0     0       0        0
# Scala                 1          0       0     0       0        1
# ASP                   1          1       9     0      32        2
# .NET                  1          0       0     0      32        0
# Objective C           0          0       0     0       0        0
# Go                    4          1       9     1      34        3
# Rust                  3          0       4     2      32        2
# PHP                   1          0       1     0       0        0
# Ruby                  1          0       1     0       0        1
# Perl                  0          0       0     0      32        1

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(style="white")
import itertools
# Out:
# /Users/pragyakaushik/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
fig, axes = plt.subplots(19, 1, sharex=True, figsize=(10,18))
fig.suptitle('Languages VS Job Categories')

# set palette 
palette = itertools.cycle(sns.color_palette())

idx = 0
for item in title_categories_list[::-1]:
    c = next(palette)
    sns.barplot(ax=axes[idx], x=new_df.index, y=new_df[item], color=c)
    axes[idx].set_title(item, fontsize=15, loc='left',pad=-14)
    axes[idx].set(xlabel=None, ylabel='frequency') 
    if idx == 18:
        axes[idx].set_xticklabels(
            axes[idx].get_xticklabels(), 
            rotation=45, 
            horizontalalignment='right',
            fontweight='light',
            fontsize=14
        )
    idx+=1
